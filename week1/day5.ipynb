# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/IamCreateAI/Ruyi-Mini-7B',
#  '/answerdotai/ModernBERT-base',
#  '/Datou1111/shou_xin',
#  '/meta-llama/Llama-3.3-70B-Instruct',
#  '/answerdotai/ModernBERT-large',
#  '/models',
#  '/spaces/JeffreyXiang/TRELLIS',
#  '/spaces/HuggingFaceH4/blogpost-scaling-test-time-compute',
#  '/spaces/multimodalart/flux-style-shaping',
#  '/spaces/Kwai-Kolors/Kolors-Virtual-Try-On',
#  '/spaces/OAOA/InvSR',
#  '/spaces',
#  '/datasets/HuggingFaceTB/finemath',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/O1-OPEN/OpenO1-SFT',
#  '/datasets/HuggingFaceFW/fineweb-2',
#  '/datasets/amphora/QwQ-LongCoT-130K',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/peft',
#  '/docs/transformers.js',
#  '/docs/timm',
#  '/docs/trl',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'status page', 'url': 'https://status.huggingface.co/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Trending on
# this week
# Models
# IamCreateAI/Ruyi-Mini-7B
# Updated
# 6 days ago
# •
# 9.52k
# •
# 401
# answerdotai/ModernBERT-base
# Updated
# 3 days ago
# •
# 10.7k
# •
# 309
# Datou1111/shou_xin
# Updated
# 14 days ago
# •
# 30.3k
# •
# 699
# meta-llama/Llama-3.3-70B-Instruct
# Updated
# 1 day ago
# •
# 244k
# •
# 1.25k
# answerdotai/ModernBERT-large
# Updated
# 3 days ago
# •
# 3.22k
# •
# 179
# Browse 400k+ models
# Spaces
# Running
# on
# Zero
# 1.9k
# 🏢
# TRELLIS
# Scalable and Versatile 3D Generation from images
# Running
# 339
# 📝
# Scaling test-time compute
# Running
# on
# Zero
# 510
# 🚀
# Flux Style Shaping
# Optical illusions and style transfer with FLUX
# Running
# on
# CPU Upgrade
# 6.16k
# 👕
# Kolors Virtual Try-On
# Running
# on
# Zero
# 175
# 🌍
# InvSR
# Image Super-resolution via Diffusion Inversion
# Browse 150k+ applications
# Datasets
# HuggingFaceTB/finemath
# Updated
# 3 days ago
# •
# 2.66k
# •
# 78
# fka/awesome-chatgpt-prompts
# Updated
# Sep 3
# •
# 6.7k
# •
# 6.6k
# O1-OPEN/OpenO1-SFT
# Updated
# 6 days ago
# •
# 1.91k
# •
# 245
# HuggingFaceFW/fineweb-2
# Updated
# 15 days ago
# •
# 80.1k
# •
# 349
# amphora/QwQ-LongCoT-130K
# Updated
# about 17 hours ago
# •
# 1.53k
# •
# 93
# Browse 100k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 366 models
# •
# 1.76k followers
# AI at Meta
# Enterprise
# company
# •
# 2.05k models
# •
# 3.84k followers
# Amazon Web Services
# company
# •
# 21 models
# •
# 2.45k followers
# Google
# company
# •
# 911 models
# •
# 5.81k followers
# Intel
# company
# •
# 217 models
# •
# 2.07k followers
# Microsoft
# company
# •
# 351 models
# •
# 6.32k followers
# Grammarly
# company
# •
# 10 models
# •
# 102 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 187 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 136,640
# State-of-the-art ML for Pytorch, TensorFlow, and JAX.
# Diffusers
# 26,769
# State-of-the-art diffusion models for image and audio generation in PyTorch.
# Safetensors
# 2,961
# Simple, safe way to store and distribute neural networks weights safely and quickly.
# Hub Python Library
# 2,179
# Client library for the HF Hub: manage repositories from your Python runtime.
# Tokenizers
# 9,168
# Fast tokenizers, optimized for both research and production.
# PEFT
# 16,776
# Parameter efficient finetuning methods for large models.
# Transformers.js
# 12,432
# State-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.
# timm
# 32,676
# State-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.
# TRL
# 10,397
# Train transformer language models with reinforcement learning.
# Datasets
# 19,381
# Access and share datasets for computer vision, audio, and NLP tasks.
# Text Generation Inference
# 9,495
# Toolkit to serve Large Language Models.
# Accelerate
# 8,088
# Easily train and use PyTorch models with multi-GPU, TPU, mixed-precision.
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# about (Sergei)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Sergei
# about
# Follow
# Renumathi's profile picture
# selvivincent's profile picture
# Kalaipriya's profile picture
# 3
# 					followers
# ·
# 0 following
# AI & ML interests
# None yet
# Organizations
# None yet
# models
# None public yet
# datasets
# None public yet
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# Evaluating Audio Reasoning with Big Bench Audio
# By
# mhillsmith
# December 20, 2024
# guest
# •
# 10
# Community Articles
# view all
# 20+ Free and Paid Digital Marketing Strategies to Automate Repetitive Tasks
# By
# Markets
# •
# 2 days ago
# •
# 1
# Tags generation dataset 🧠
# By
# zino36
# •
# 2 days ago
# •
# 1
# AI Agents in Action: Managing GitHub Issues with KaibanJS
# By
# darielnoel
# •
# 3 days ago
# **Intelligence Potentiation: An Evolutionary Perspective on AI Agent Designs**
# By
# KnutJaegersberg
# •
# 3 days ago
# •
# 3
# MINERVA: A Multi-Agent LLM System for Digital Scam Protection
# By
# dcarpintero
# •
# 4 days ago
# Mastering Iterative Prompting for Optimized AI Code Generation
# By
# luigi12345
# •
# 4 days ago
# •
# 1
# SILMA RAGQA V1.0: A Comprehensive Benchmark for Evaluating LLMs on RAG QA Use-Cases
# By
# karimouda
# •
# 5 days ago
# •
# 1
# FuseChat-3.0: Preference Optimization for Implicit Model Fusion
# By
# Wanfq
# •
# 5 days ago
# •
# 2
# Tutorial: Quantizing Llama 3+ Models for Efficient Deployment
# By
# theeseus-ai
# •
# 8 days ago
# •
# 3
# How to Expand Your AI Music Generations of 30 Seconds to Several Minutes
# By
# theeseus-ai
# •
# 10 days ago
# •
# 1
# 🇪🇺✍️ EU AI Act: Systemic Risks in the First CoP Draft Comments ✍️🇪🇺
# By
# yjernite
# •
# 11 days ago
# •
# 11
# Building an AI-powered search engine from scratch
# By
# as-cle-bert
# •
# 11 days ago
# •
# 8
# MotionLCM-V2: Improved Compression Rate for Multi-Latent-Token Diffusion
# By
# wxDai
# •
# 12 days ago
# •
# 12
# RLHF 101: A Technical Dive into RLHF
# By
# GitBag
# •
# 12 days ago
# •
# 4
# [Talk Arena](https://talkarena.org)
# By
# WillHeld
# •
# 13 days ago
# •
# 1
# Multimodal RAG with Colpali, Milvus and VLMs
# By
# saumitras
# •
# 13 days ago
# •
# 2
# In Honour of This Year's NeurIPs Test of Time Paper Awardees
# By
# Jaward
# •
# 13 days ago
# •
# 2
# Power steering: Squeeze massive power from small LLMs
# By
# ucheog
# •
# 14 days ago
# •
# 4
# Exploring the Power of KaibanJS v0.11.0 🚀
# By
# darielnoel
# •
# 14 days ago
# •
# 1
# **Building a Custom Retrieval System with Motoko and Node.js**
# By
# theeseus-ai
# •
# 14 days ago
# •
# 1
# Finally, a Replacement for BERT: Introducing ModernBERT
# By
# bwarner
# December 19, 2024
# guest
# •
# 321
# Bamba: Inference-Efficient Hybrid Mamba2 Model
# By
# Linsong-C
# December 18, 2024
# guest
# •
# 31
# Welcome the Falcon 3 Family of Open Models!
# By
# FalconLLM
# December 17, 2024
# •
# 102
# Benchmarking Language Model Performance on 5th Gen Xeon at GCP
# By
# MatrixYao
# December 17, 2024
# •
# 2
# Introducing the Synthetic Data Generator - Build Datasets with Natural Language
# By
# davidberenstein1957
# December 16, 2024
# •
# 61
# LeMaterial: an open source initiative to accelerate materials discovery and research
# By
# AlexDuvalinho
# December 10, 2024
# guest
# •
# 30
# Hugging Face models in Amazon Bedrock
# By
# pagezyhf
# December 9, 2024
# •
# 8
# Open Preference Dataset for Text-to-Image Generation by the 🤗 Community
# By
# davidberenstein1957
# December 9, 2024
# •
# 47
# Welcome PaliGemma 2 – New vision language models by Google
# By
# merve
# December 5, 2024
# •
# 118
# “How good are LLMs at fixing their mistakes? A chatbot arena experiment with Keras and TPUs
# By
# martin-gorner
# December 5, 2024
# •
# 12
# Rethinking LLM Evaluation with 3C3H: AraGen Benchmark and Leaderboard
# By
# alielfilali01
# December 4, 2024
# guest
# •
# 28
# Investing in Performance: Fine-tune small models with LLM insights  - a CFM case study
# By
# oahouzi
# December 3, 2024
# •
# 25
# Rearchitecting Hugging Face Uploads and Downloads
# By
# port8080
# November 26, 2024
# •
# 37
# SmolVLM - small yet mighty Vision Language Model
# By
# andito
# November 26, 2024
# •
# 145
# Previous
# 1
# 2
# 3
# ...
# 36
# Next
# Community Articles
# view all
# 20+ Free and Paid Digital Marketing Strategies to Automate Repetitive Tasks
# By
# Markets
# •
# 2 days ago
# •
# 1
# Tags generation dataset 🧠
# By
# zino36
# •
# 2 days ago
# •
# 1
# AI Agents in Action: Managing GitHub Issues with KaibanJS
# By
# darielnoel
# •
# 3 days ago
# **Intelligence Potentiation: An Evolutionary Perspective on AI Agent Designs**
# By
# KnutJaegersberg
# •
# 3 days ago
# •
# 3
# MINERVA: A Multi-Agent LLM System for Digital Scam Protection
# By
# dcarpintero
# •
# 4 days ago
# Mastering Iterative Prompting for Optimized AI Code Generation
# By
# luigi12345
# •
# 4 days ago
# •
# 1
# SILMA RAGQA V1.0: A Comprehensive Benchmark for Evaluating LLMs on RAG QA Use-Cases
# By
# karimouda
# •
# 5 days ago
# •
# 1
# FuseChat-3.0: Preference Optimization for Implicit Model Fusion
# By
# Wanfq
# •
# 5 days ago
# •
# 2
# Tutorial: Quantizing Llama 3+ Models for Efficient Deployment
# By
# theeseus-ai
# •
# 8 days ago
# •
# 3
# How to Expand Your AI Music Generations of 30 Seconds to Several Minutes
# By
# theeseus-ai
# •
# 10 days ago
# •
# 1
# 🇪🇺✍️ EU AI Act: Systemic Risks in the First CoP Draft Comments ✍️🇪🇺
# By
# yjernite
# •
# 11 days ago
# •
# 11
# Building an AI-powered search engine from scratch
# By
# as-cle-bert
# •
# 11 days ago
# •
# 8
# MotionLCM-V2: Improved Compression Rate for Multi-Latent-Token Diffusion
# By
# wxDai
# •
# 12 days ago
# •
# 12
# RLHF 101: A Technical Dive into RLHF
# By
# GitBag
# •
# 12 days ago
# •
# 4
# [Talk Arena](https://talkarena.org)
# By
# WillHeld
# •
# 13 days ago
# •
# 1
# Multimodal RAG with Colpali, Milvus and VLMs
# By
# saumitras
# •
# 13 days ago
# •
# 2
# In Honour of This Year's NeurIPs Test of Time Paper Awardees
# By
# Jaward
# •
# 13 days ago
# •
# 2
# Power steering: Squeeze massive power from small LLMs
# By
# ucheog
# •
# 14 days ago
# •
# 4
# Exploring the Power of KaibanJS v0.11.0 🚀
# By
# darielnoel
# •
# 14 days ago
# •
# 1
# **Building a Custom Retrieval System with Motoko and Node.js**
# By
# theeseus-ai
# •
# 14 days ago
# •
# 1
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU for Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# AI at Meta
# Enterprise
# company
# •
# 2.05k models
# •
# 3.84k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 262 followers
# Arm
# Enterprise
# company
# •
# 115 followers
# Bloomberg
# Enterprise
# company
# •
# 2 models
# •
# 135 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 8 models
# •
# 92 followers
# Lightricks
# Enterprise
# company
# •
# 3 models
# •
# 398 followers
# Aledade Inc
# Enterprise
# company
# •
# 54 followers
# Stability AI
# Enterprise
# company
# •
# 96 models
# •
# 9.36k followers
# Nutanix
# Enterprise
# company
# •
# 245 models
# •
# 40 followers
# creditkarma
# Enterprise
# company
# •
# 35 followers
# Gretel.ai
# Enterprise
# company
# •
# 8 models
# •
# 74 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 81 followers
# HOVER External
# Enterprise
# company
# •
# 26 followers
# Liquid AI
# Enterprise
# company
# •
# 88 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 15k followers
# Orange
# Enterprise
# company
# •
# 4 models
# •
# 151 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 110 followers
# Fidelity Investments
# Enterprise
# company
# •
# 117 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 363 followers
# Mistral AI_
# Enterprise
# company
# •
# 21 models
# •
# 3.53k followers
# IBM Granite
# Enterprise
# company
# •
# 70 models
# •
# 688 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 49 followers
# HiddenLayer
# Enterprise
# company
# •
# 49 followers
# Ekimetrics
# Enterprise
# company
# •
# 48 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 36 followers
# BCG X
# Enterprise
# company
# •
# 29 followers
# Qualcomm
# Enterprise
# company
# •
# 153 models
# •
# 364 followers
# StepStone Online Recruiting
# Enterprise
# company
# •
# 32 followers
# Shopify
# Enterprise
# company
# •
# 374 followers
# Together
# Enterprise
# company
# •
# 27 models
# •
# 466 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 187 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 112 followers
# Jusbrasil
# Enterprise
# company
# •
# 78 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 64 models
# •
# 1.06k followers
# Chegg Inc
# Enterprise
# company
# •
# 77 followers
# Liberty Mutual
# Enterprise
# company
# •
# 42 followers
# Arcee AI
# Enterprise
# company
# •
# 130 models
# •
# 276 followers
# Kakao Corp.
# Enterprise
# company
# •
# 41 followers
# Gsk-tech
# Enterprise
# company
# •
# 33 followers
# Widn AI
# Enterprise
# company
# •
# 27 followers
# BRIA AI
# Enterprise
# company
# •
# 27 models
# •
# 1.16k followers
# Prezi
# Enterprise
# company
# •
# 31 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Higher rate limits for serverless inference
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# TPU v5e 1x1
# 22 vCPU
# 44 GB
# Google TPU v5e
# 16 GB
# $1.20
# TPU v5e 2x2
# 110 vCPU
# 186 GB
# Google TPU v5e
# 64 GB
# $4.75
# TPU v5e 2x4
# 220 vCPU
# 380 GB
# Google TPU v5e
# 128 GB
# $9.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Dataset Viewer
# : Activate it on private datasets
# Inference API
# : Get x20 higher rate limits on Serverless API
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# community forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Loading
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Gemma Pending Approval
# Beginners
# 2
# 10
# December 23, 2024
# Llama 3.2 1B Model for Multilingual Translation
# Models
# 0
# 14
# December 23, 2024
# Idefics3 preprocessing
# Models
# 1
# 29
# December 23, 2024
# Audio Course: Unit 6 Unable lower loss during training of Speech T5
# Course
# 0
# 4
# December 23, 2024
# Should I just get more RAM?
# Beginners
# 4
# 32
# December 22, 2024
# Best model for translating English to Japanese
# Models
# 4
# 213
# December 22, 2024
# Can't run on ZeroGPU
# Spaces
# 1
# 11
# December 22, 2024
# Need help in dealing with out of bounds
# Beginners
# 16
# 20
# December 23, 2024
# Workspace streamlit
# Spaces
# 4
# 18
# December 22, 2024
# How to separate Multi-head weight from q, k, v matrices?
# 🤗Transformers
# 0
# 6
# December 22, 2024
# Combine multiple Lora's for group photo?
# Intermediate
# 0
# 6
# December 22, 2024
# Hide system prompt or system instruction
# Beginners
# 4
# 27
# December 21, 2024
# Gradio can't change height with the screen
# Beginners
# 3
# 9
# December 22, 2024
# No Biases for Llama-3.2-3B-Instruct
# Models
# 0
# 15
# December 22, 2024
# Model that can generate both text and image as output
# Research
# 4
# 58
# December 21, 2024
# How to set different learning rates for different parameters in the model?
# Beginners
# 7
# 30
# December 17, 2024
# Talkie AI got remove from app store -any alternative ai chat?
# Beginners
# 4
# 1480
# December 18, 2024
# "Load Diffusion Model" and "Unet Loader (GGUF)" null/undefined
# Beginners
# 6
# 292
# December 20, 2024
# Issues getting the same results from the original pytorch model when converting to coreml
# Beginners
# 0
# 6
# December 22, 2024
# Prediction on Causal Language models
# Beginners
# 0
# 10
# December 22, 2024
# Target is out of bounds
# Beginners
# 5
# 1658
# December 22, 2024
# Dimension problem
# Beginners
# 26
# 26
# December 21, 2024
# Cuda Out of Memory with Multi-GPU Accelerate for gemma-2b
# 🤗Accelerate
# 1
# 68
# December 22, 2024
# Lm studio and Chat ui doesn't work with module
# Beginners
# 11
# 39
# December 21, 2024
# 404 error on carbon emission calculation
# Site Feedback
# 1
# 9
# December 21, 2024
# Gradio cannot share link
# Beginners
# 0
# 5
# December 21, 2024
# Understanding State Management with Gradio and LangGraph
# Beginners
# 1
# 24
# December 21, 2024
# List of `size_categories`
# 🤗Datasets
# 1
# 17
# December 21, 2024
# Spaces dedicated gpu limit
# Spaces
# 1
# 16
# December 19, 2024
# Extending the tokenizer affects model generation
# Intermediate
# 3
# 10
# December 19, 2024
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# White papers, Ebooks, Webinars
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# Advanced Security
# Enterprise-grade security features
# GitHub Copilot
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 40.2k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 137k
# 27.4k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image and audio generation in PyTorch and FLAX.
# Python
# 26.8k
# 5.5k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.4k
# 2.7k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 16.8k
# 1.7k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.1k
# 997
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.6k
# 487
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 275 repositories
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 26,769
# Apache-2.0
# 5,503
# 380
# (9 issues need help)
# 161
# Updated
# Dec 23, 2024
# Google-Cloud-Containers
# Public
# Hugging Face Deep Learning Containers (DLCs) for Google Cloud
# huggingface/Google-Cloud-Containers’s past year of commit activity
# Dockerfile
# 133
# Apache-2.0
# 19
# 6
# 11
# Updated
# Dec 23, 2024
# optimum-intel
# Public
# 🤗 Optimum Intel: Accelerate inference with Intel optimization tools
# huggingface/optimum-intel’s past year of commit activity
# Jupyter Notebook
# 424
# Apache-2.0
# 115
# 20
# 22
# Updated
# Dec 23, 2024
# optimum-habana
# Public
# Easy and lightning fast training of 🤗 Transformers on Habana Gaudi processor (HPU)
# huggingface/optimum-habana’s past year of commit activity
# Python
# 162
# Apache-2.0
# 219
# 11
# (1 issue needs help)
# 42
# Updated
# Dec 23, 2024
# hub-docs
# Public
# Docs of the Hugging Face Hub
# huggingface/hub-docs’s past year of commit activity
# Handlebars
# 310
# Apache-2.0
# 259
# 90
# 26
# Updated
# Dec 23, 2024
# agents
# Public
# 🤗 Agents: the simplest building blocks to build and run LLM agents.
# huggingface/agents’s past year of commit activity
# Python
# 11
# Apache-2.0
# 0
# 0
# 0
# Updated
# Dec 22, 2024
# optimum-neuron
# Public
# Easy, fast and very cheap training and inference on AWS Trainium and Inferentia chips.
# huggingface/optimum-neuron’s past year of commit activity
# Jupyter Notebook
# 213
# Apache-2.0
# 65
# 20
# 6
# Updated
# Dec 22, 2024
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 136,641
# Apache-2.0
# 27,356
# 999
# (2 issues need help)
# 528
# Updated
# Dec 22, 2024
# text-generation-inference
# Public
# Large Language Model Text Generation Inference
# huggingface/text-generation-inference’s past year of commit activity
# Python
# 9,495
# Apache-2.0
# 1,106
# 152
# 23
# Updated
# Dec 22, 2024
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 10,398
# Apache-2.0
# 1,340
# 107
# 38
# Updated
# Dec 22, 2024
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# deep-learning
# transformers
# Footer
# © 2024 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 475 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 17h
# Report this post
# 8 steps are the new 50 steps 🔥
#
# Enable few-step inference on Flux Control, Fill, and Redux pipelines from
# Black Forest Labs
# by combining them with turbo LoRAs. Works with Flux Control LoRAs, too.
#
# Check out the documentation to learn more:
# https://lnkd.in/gVtAg9RM
# 108
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Philipp Schmid
# Technical Lead & LLMs at Hugging Face  🤗  | AWS ML HERO 🦸🏻♂️
# 3d
# Report this post
# ModernBERT, BERT revisited in the age of LLMs and Generative AI!
# LightOn
# and
# Answer.ai
# modernized BERT! Improved architecture with 8192 context length, flash attention, and trained on 2T tokens. ModernBERT outperforms version BERT and RoBERTa versions! 👀
#
# TL;DR;
# 2️⃣ Comes in 2 sizes base (139M) and large (395M)
# 🚀 Better performance across all metrics than the original BERT
# 📏 8,192 token context length (16x longer than BERT)
# ⚡ Modern architecture with Flash Attention 2, RoPE embeddings, and alternating attention
# 📚 Trained on 2 trillion tokens, primarily English and Code
# 💨 2-4x faster than other models with mixed-length inputs
# 🔓 Released under Apache 2.0
# 🤗 Available on
# Hugging Face
# and Transformers (main)
#
# Models:
# https://lnkd.in/ethiJ2xh
# Blog:
# https://lnkd.in/ebiEzb4P
# Paper:
# https://lnkd.in/ezR8MUBF
# 2,226
# 70 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Philipp Schmid
# Technical Lead & LLMs at Hugging Face  🤗  | AWS ML HERO 🦸🏻♂️
# 2d
# Report this post
# The only fine-tuning guide you need for 2025 ‼️ Excited to share “How to fine-tune open LLMs in 2025 with
# Hugging Face
# ” covering everything from Q-LoRA to Spectrum methods with focus on optimization, efficiency and distributed training. 👀
#
# Fine-tuning still matters for specialized use cases despite better models - especially for consistency, domain expertise, controlling output style, or reducing costs. In this guide you will learn how:
#
# 🎯 Define good use cases for fine-tuning vs. prompting
# 🛠️ Set up your development environment using Hugging Face libraries
# 📚 Create and prepare datasets in conversation format
# ⚡ Use Q-LoRA for efficient 4-bit training or Spectrum method to selectively fine-tune important layers
# 💨 Speed up training with Flash Attention and Liger Kernels
# 💻 Scale across multiple GPUs with DeepSpeed and accelerate
# 📊 Test and evaluate models with evaluation harness
# 🔥 Run for production using TGI/vLLM
#
# Blog:
# https://lnkd.in/egXtAwz5
# 1,361
# 31 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 47,463 followers
# 2d
# Report this post
# NOW you can add AI to your Slack, Discord in just few steps with Gradio!🤩
#
# 🔥Create Slack apps, Discord bots, or Intercom-style website widgets in ANY modality (Text, image, Video, Audio, Omni etc)! Keep reading to learn how ⬇️
#
# Guide: 🚀 Creating a Slack Bot from a Gradio App 🚀
# Read here:
# https://lnkd.in/g2_Bydrj
# 🤎Do you love building stuff with Gradio? Support us on GitHub:
# Gradio.dev
# …more
# 78
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel V.
# Machine Learning Librarian@🤗 | Championing Open Science & Machine Learning
# 2d
# Report this post
# Introducing FineWeb-C 🌐🎓, a community-built dataset for improving language models in ALL languages.
#
# Inspired by FineWeb-Edu the community is labelling the educational quality of texts for many languages.
#
# 318 annotators, 32K+ annotations, 12 languages - and growing!🌍
# 75
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 2d
# Report this post
# Fine-tune ColPali for your multimodal RAG use case 🔥
#
# ColPali just landed to
# Hugging Face
# transformers and I have built a simple fine-tuning tutorial with QLoRA 🤗
# You can fine-tune the model with 32 GB VRAM with batch size of 4 (which can run on Colab A100)
# Link in comments 💬
# 346
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# 🤖 Avthar Sewrathan
# AI and Developer Product Leader | I talk about using AI and building AI apps
# 3d
# Report this post
# TIL: You can now load any
# Hugging Face
# dataset into PostgreSQL with just 1 line of SQL 🤯
#
# All thanks to the pgai PostgreSQL extension.
#
# Shoutout to
# Matvey Arye
# from the
# Timescale
# AI engineering team for implementing this.
#
# Learn more about using PostgreSQL with HuggingFace datasets in the HuggingFace docs:
# https://lnkd.in/eS4hqSDq
# #postgresql
# #huggingface
# #opensource
# 206
# 16 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Argilla
# 10,285 followers
# 2d
# Report this post
# 🎢 Push to Hub: Export your dataset to the Hugging Face Hub directly from the Argilla UI.
#
# We’re super excited to announce that we've closed the loop: now you can load a dataset from the Hub, open it on
# Argilla
# UI, label it, and push the annotated dataset to the Hub. All this without a line of code!
#
#
# 𝗪𝗵𝘆 𝘀𝗵𝗼𝘂𝗹𝗱 𝘆𝗼𝘂 𝘂𝘀𝗲 𝗶𝘁?
#
# Your AI project's impact depends heavily on the effort and care you put into your data. This new feature enables you to iterate faster and make annotated data available in the right format for training and evaluation.
#
#
# 𝗛𝗼𝘄 𝗱𝗼𝗲𝘀 𝗶𝘁 𝘄𝗼𝗿𝗸?
#
# 1️⃣ Import initial data from a CSV or any format to Hugging Face
# 2️⃣ Load it into the Argilla UI and configure the annotation task
# 3️⃣ Annotate your dataset
# 🚀 Click on “Push to Hub” and share the dataset with your team (or the entire world)
#
# 👉 𝗥𝗲𝗮𝗱𝘆 𝘁𝗼 𝘁𝗿𝘆 𝗶𝘁 𝗼𝘂𝘁?
#
# Get started here:
# https://lnkd.in/dhA-swR5
# Release highlights:
# https://lnkd.in/dbdQXG-W
# 38
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel V.
# Machine Learning Librarian@🤗 | Championing Open Science & Machine Learning
# 2d
# Report this post
# Hot take: shipping BERT-sized models in 2025 will benefit far more people than sharing an LLM overfitted to some saturated leaderboards
#
# We're already seeing ModernBERT finetunes on the
# Hugging Face
# Hub. My guess is we'll see hundreds of these by the end of 2025.
# 95
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 47,463 followers
# 3d
# Edited
# Report this post
# 🤯🔥LEARN HOW TO CREATE interactive agentic chatbots using Gradio that are capable of showcasing the Thoughts, Tasks, and interim responses of Multiple Agents as you await the final answer from your AI assistant.
#
# 🎯 Customer Support multi-agents with
# CrewAI
# and
# Gradio
# Showcasing here, a user-friendly, high-performing multi-agent gradio app. TO operate it, simply enter a webpage URL along with your questions related to that page, and in turn receive a high-quality response from the CrewAI Multi-Agent setup.
#
# 🚀Access this app on
# Hugging Face
# Spaces:
# https://lnkd.in/g6kXp_D2
# …more
# 87
# 1 Comment
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Perplexity
# Software Development
# San Francisco, California
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Analyst jobs
# 694,057 open jobs
# Intelligence Specialist jobs
# 7,156 open jobs
# Manager jobs
# 1,880,925 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Director jobs
# 1,220,357 open jobs
# Associate jobs
# 1,091,945 open jobs
# Python Developer jobs
# 46,642 open jobs
# Evangelist jobs
# 5,068 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Quantitative Analyst jobs
# 19,570 open jobs
# Program Manager jobs
# 243,900 open jobs
# Data Science Specialist jobs
# 2,441 open jobs
# Lead Software Engineer jobs
# 68,215 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 7 total rounds
# Last Round
# Series D
# Feb 16, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Intern jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Scientist jobs
# Developer jobs
# Research Intern jobs
# Analyst jobs
# Intelligence Specialist jobs
# Quantitative Analyst jobs
# Technician jobs
# Data Science Specialist jobs
# Project Manager jobs
# Summer Intern jobs
# Manager jobs
# Senior Staff Engineer jobs
# PHD jobs
# Trader jobs
# Researcher jobs
# Data Scientist jobs
# Writer jobs
# Data Analyst jobs
# Product Designer jobs
# Back End Developer jobs
# Spring Intern jobs
# Program Manager jobs
# Technology Officer jobs
# Software Intern jobs
# Security Professional jobs
# Senior Software Engineer jobs
# Python Developer jobs
# Engineering Manager jobs
# Web Developer jobs
# Graduate jobs
# Full Stack Engineer jobs
# Professor jobs
# Head jobs
# Verification Manager jobs
# User Experience Designer jobs
# Recruiter jobs
# Chief Executive Officer jobs
# Associate jobs
# Support Developer jobs
# Senior Firmware Engineer jobs
# Marketing Manager jobs
# Modeling Engineer jobs
# Designer jobs
# Automation Lead jobs
# Options Trader jobs
# Agile Coach jobs
# Research Engineer jobs
# Software Quality Assurance Analyst jobs
# User Experience Manager jobs
# Technical Intern jobs
# Junior Network Engineer jobs
# Information Technology Recruiter jobs
# User Researcher jobs
# Player jobs
# Engineering Project Manager jobs
# Digital Strategist jobs
# LinkedIn
# © 2024
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# Twitter page
# Webpage Title:
# x.com
# Webpage Contents:

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# "You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nTrending on\nthis week\nModels\nIamCreateAI/Ruyi-Mini-7B\nUpdated\n6 days ago\n•\n9.52k\n•\n401\nanswerdotai/ModernBERT-base\nUpdated\n3 days ago\n•\n10.7k\n•\n309\nDatou1111/shou_xin\nUpdated\n14 days ago\n•\n30.3k\n•\n699\nmeta-llama/Llama-3.3-70B-Instruct\nUpdated\n1 day ago\n•\n244k\n•\n1.25k\nanswerdotai/ModernBERT-large\nUpdated\n3 days ago\n•\n3.22k\n•\n179\nBrowse 400k+ models\nSpaces\nRunning\non\nZero\n1.9k\n🏢\nTRELLIS\nScalable and Versatile 3D Generation from images\nRunning\n339\n📝\nScaling test-time compute\nRunning\non\nZero\n510\n🚀\nFlux Style Shaping\nOptical illusions and style transfer with FLUX\nRunning\non\nCPU Upgrade\n6.16k\n👕\nKolors Virtual Try-On\nRunning\non\nZero\n175\n🌍\nInvSR\nImage Super-resolution via Diffusion Inversion\nBrowse 150k+ applications\nDatasets\nHuggingFaceTB/finemath\nUpdated\n3 days ago\n•\n2.66k\n•\n78\nfka/awesome-chatgpt-prompts\nUpdated\nSep 3\n•\n6.7k\n•\n6.6k\nO1-OPEN/OpenO1-SFT\nUpdated\n6 days ago\n•\n1.91k\n•\n245\nHuggingFaceFW/fineweb-2\nUpdated\n15 days ago\n•\n80.1k\n•\n349\namphora/QwQ-LongCoT-130K\nUpdated\nabout 17 hours ago\n•\n1.53k\n•\n93\nBrowse 100k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n366 models\n•\n1.76k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.05k models\n•\n3.84k followers\nAmazon Web Services\ncompany\n•\n21 models\n•\n2.45k followers\nGoogle\ncompany\n•\n911 models\n•\n5.81k followers\nIntel\ncompany\n•\n217 models\n•\n2.07k followers\nMicrosoft\ncompany\n•\n351 models\n•\n6.32k followers\nGrammarly\ncompany\n•\n10 models\n•\n102 followers\nWriter\nEnterprise\ncompany\n•\n17 models\n•\n187 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n136,640\nState-of-the-art ML for Pytorch, TensorFlow, and JAX.\nDiffusers\n26,769\nState-of-the-art diffusion models for image and audio generation in PyTorch.\nSafetensors\n2,961\nSimple, safe way to store and distribute neural networks weights safely and quickly.\nHub Python Library\n2,179\nClient library for the HF Hub: manage repositories from your Python runtime.\nTokenizers\n9,168\nFast tokenizers, optimized for both research and production.\nPEFT\n16,776\nParameter efficient finetuning methods for large models.\nTransformers.js\n12,432\nState-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.\ntimm\n32,676\nState-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.\nTRL\n10,397\nTrain tra ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.com")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.com/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.com/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.com/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.com/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ---
#
# ## About Us
#
# Hugging Face is at the forefront of building the AI community that is shaping the future of machine learning (ML). Our platform allows the community to create, discover, and collaborate on models, datasets, and applications, making it the ideal space for innovation in artificial intelligence.
#
# ### Our Mission
# We aim to democratize AI by providing open-source tools and a collaborative environment. With over 50,000 organizations leveraging our platform—from tech giants like Google, Microsoft, and Amazon Web Services to innovative startups—it's clear that Hugging Face is a significant player in the ML landscape.
#
# ---
#
# ## Our Offerings
#
# ### Models
# Explore over **400,000 models** across various tasks and functionalities that are continuously updated and improved. Our models are designed to push the boundaries of what's possible in AI.
#
# ### Datasets
# Access and share **more than 100,000 datasets** tailored for computer vision, natural language processing (NLP), and audio tasks, making it easy to find the data you need for your projects.
#
# ### Spaces
# Check out our **150,000+ applications** hosted in the Hugging Face Spaces where we encourage creativity and experimentation, allowing users to build and share innovative ML applications.
#
# ### Enterprise Solutions
# For businesses, we offer enterprise-grade services starting at **$20/user/month**, including:
# - Advanced security and access controls
# - Dedicated support
# - Private dataset viewers
# - Single Sign-On capabilities
#
# ---
#
# ## Company Culture
#
# At Hugging Face, we foster a culture of collaboration and inclusivity. We believe in the power of open-source technology and encourage our employees to innovate freely. Our community-driven ethos is reflected in our commitment to maintaining an open platform where ideas can be shared and developed.
#
# ---
#
# ## Careers
#
# Join a community of passionate individuals who are shaping the future of AI. We are constantly searching for talented professionals to join our diverse team. Explore exciting career opportunities and become part of a mission-driven organization where your work will leave a lasting impact.
#
# Stay updated on our current job openings by visiting our careers page.
#
# ---
#
# ## Customer Testimonials
#
# More than 50,000 organizations trust us with their machine learning objectives:
#
# - **Meta**: Collaborating on advanced AI initiatives.
# - **Intel**: Building superior models for diverse applications.
# - **Grammarly**: Enhancing user experience through state-of-the-art technology.
#
# Whether you're an individual developer, a startup, or an enterprise, Hugging Face provides the tools and community support to accelerate your machine learning projects.
#
# ---
#
# **Join us in building the future of AI!**
# Explore more at [Hugging Face](https://huggingface.co) or connect with us on [GitHub](https://github.com/huggingface), [Twitter](https://twitter.com/huggingface), and [LinkedIn](https://www.linkedin.com/company/huggingface/).
#
# ---
#
# *This brochure contains essential information for prospective customers, investors, and recruits about Hugging Face—a pioneering AI company dedicated to innovation and community collaboration in machine learning.*

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ## About Us
# Welcome to **Hugging Face**, where we are not just a company; we are a thriving **AI community** dedicated to building the future. As the leading platform for machine learning collaboration, we empower individuals and organizations to come together on **models, datasets**, and **applications**.
#
# ## What We Offer
# - **Models**: Access to over 400,000 cutting-edge models. From text to image processing, we have the resources to accelerate your ML projects.
# - **Datasets**: A repository of over 100,000 open datasets spanning various domains such as computer vision, audio, and NLP tasks.
# - **Spaces**: Explore and create interactive applications that run directly in the browser or on powerful infrastructure with a few clicks.
# - **Enterprise Solutions**: Tailored services for businesses, offering enterprise-grade security, access controls, and premium support.
#
# ### Popular Features
# - **Open Source**: We are building foundational ML tooling with community contributions, including state-of-the-art libraries like **Transformers**, **Diffusers**, and **Tokenizers**.
# - **Compute Resources**: Optimized deployment of models using our robust infrastructure, starting from just $0.60/hour for GPU.
#
# ## Our Customers
# More than **50,000 organizations** trust Hugging Face, including industry leaders like:
# - **Microsoft**
# - **Google**
# - **Amazon Web Services**
# - **Intel**
# - **Meta AI**
#
# These partnerships enhance our offerings and cement our place as the go-to platform for ML collaboration.
#
# ## Company Culture
# At Hugging Face, we champion an inclusive and innovative environment where creativity thrives. We believe in:
# - **Collaboration**: Working together to solve problems and push the boundaries of AI.
# - **Community Engagement**: Actively involving our users in every step of development.
# - **Continuous Learning**: Encouraging our employees to grow and evolve within their careers.
#
# ## Careers at Hugging Face
# Join us in shaping the future of AI! We are on the lookout for passionate individuals who are eager to push the envelope in machine learning. Our flat structure fosters open communication and teamwork. Explore current job openings at our [Jobs Page](#).
#
# ## Connect With Us
# Explore our community and projects through our [Social Media](#) channels. We invite you to **sign up** to start collaborating and transforming the AI landscape today!
#
# ---
# **Hugging Face**: The home of machine learning innovation, where your ideas and our technology come together to redefine what's possible.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 2 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!
#             </span>
#         </td>
#     </tr>
# </table>
